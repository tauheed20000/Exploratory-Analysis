# %% [markdown]
# World Freedom Index

# %% [markdown]
# # Overview
#
# The World Press Freedom Index (WPFI) is an annual ranking of countries compiled and published by Reporters Without Borders (RSF) since 2002. This comprehensive index aims to assess and rank countries based on their press freedom records in the previous year. It provides valuable insights into the degree of freedom that journalists, news organizations, and netizens enjoy in each country, as well as the efforts made by authorities to uphold and protect this fundamental freedom.

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('World_Press_Freedom_Index[1].csv')

# %%
df.head()
# Out:
#    Unnamed: 0 Country\n   2023[6]\n   2022[7]\n   2021[8]\n     2020[9]  \
# 0           0    Norway  (001)95.18  (001)92.65  (001)93.28  (001)92.16
# 1           1   Ireland  (002)89.91   (006)88.3  (012)88.09  (013)87.40
# 2           2   Denmark  (003)89.48  (002)90.27  (004)91.43  (003)91.87
# 3           3    Sweden  (004)88.15  (003)88.84  (003)92.76  (004)90.75
# 4           4   Finland  (005)87.94  (005)88.42  (002)93.01  (002)92.07
#
#    2019[10]\n
# 0  (001)92.18
# 1  (015)85.00
# 2  (005)90.13
# 3  (003)91.69
# 4  (002)92.10

# %% [markdown]
# # Dataset Columns Information

# %% [markdown]
# # Country 🌎

# %% [markdown]
# This column contains the names of different countries. Each row corresponds to a specific country, and it serves as the primary identifier for the dataset.

# %% [markdown]
# # 2023 [6] 📅 (Rank)Points

# %% [markdown]
# This column represents the World Press Freedom Index (WPFI) rankings for the year 2023. The numbers in this column reflect the position or score of each country in terms of press freedom according to the most recent data.

# %% [markdown]
# # 2022 [7] 📅 (Rank)Points

# %% [markdown]
# This column displays the WPFI rankings for the year 2022. It provides historical data regarding the press freedom status of each country in the previous year.

# %% [markdown]
# # 2021 [8] 📅(Rank)Points

# %% [markdown]
# The column contains WPFI rankings for the year 2021. It offers insights into the press freedom situation in each country in that specific year.

# %% [markdown]
# # 2020 [9] 📅(Rank)Points

# %% [markdown]
# This column contains data related to the WPFI rankings for the year 2020, which is important for understanding the trend in press freedom over several years.

# %% [markdown]
# # 2019 [10] 📅(Rank)Points

# %% [markdown]
# The final column in the dataset provides information about the WPFI rankings for the year 2019. This historical data is crucial for tracking press freedom changes over a more extended period.

# %% [markdown]
# # Note:
# Each ranking is presented within parentheses, and the points are outside the parentheses. Here's how you can format it:

# %% [raw]
# In 2023, Norway is ranked 1st with a score of 95.18.
# In 2022, Norway was also ranked 1st with a score of 92.65.
# In 2021, Norway held the 1st position with a score of 93.28.
# In 2020, Norway was 1st with a score of 92.16.
# In 2019, Norway was ranked 1st with a score of 92.18.
# These columns collectively enable a comprehensive analysis of how press freedom has evolved over time in different countries, as measured by the World Press Freedom Index. 📈📆🏛️

# %%
df.shape
# Out:
# (181, 7)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Country\n     0
# 2023[6]\n     0
# 2022[7]\n     0
# 2021[8]\n     0
# 2020[9]       0
# 2019[10]\n    0
# dtype: int64

# %%
df.duplicated().any()
# Out:
# False

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# renaming columns name
new_column_names = ['Sr no', 'Country', '2023', '2022', '2021', '2020', '2019']

# %%
# Use the rename method to rename the columns
df.columns = new_column_names

# %% [markdown]
# # Feature splitting

# %%
df['Rank_2023']=df['2023'].str.split(')').str[0].str.split('(').str[1]
df['Points_2023']=df['2023'].str.split(')').str[1]

# %%
df['Rank_2022']=df['2022'].str.split(')').str[0].str.split('(').str[1]
df['Points_2022']=df['2022'].str.split(')').str[1]

# %%
df['Rank_2021']=df['2021'].str.split(')').str[0].str.split('(').str[1]
df['Points_2021']=df['2021'].str.split(')').str[1]

# %%
df['Rank_2021']=df['2021'].str.split(')').str[0].str.split('(').str[1]
df['Points_2021']=df['2021'].str.split(')').str[1]

# %%
df['Rank_2019']=df['2019'].str.split(')').str[0].str.split('(').str[1]
df['Points_2019']=df['2019'].str.split(')').str[1]

# %%
df.head()
# Out:
#    Sr no  Country        2023        2022        2021        2020        2019  \
# 0      0   Norway  (001)95.18  (001)92.65  (001)93.28  (001)92.16  (001)92.18
# 1      1  Ireland  (002)89.91   (006)88.3  (012)88.09  (013)87.40  (015)85.00
# 2      2  Denmark  (003)89.48  (002)90.27  (004)91.43  (003)91.87  (005)90.13
# 3      3   Sweden  (004)88.15  (003)88.84  (003)92.76  (004)90.75  (003)91.69
# 4      4  Finland  (005)87.94  (005)88.42  (002)93.01  (002)92.07  (002)92.10
#
#   Rank_2023 Points_2023 Rank_2022 Points_2022 Rank_2021 Points_2021 Rank_2019  \
# 0       001       95.18       001       92.65       001       93.28       001
# 1       002       89.91       006        88.3       012       88.09       015
# 2       003       89.48       002       90.27       004       91.43       005
# 3       004       88.15       003       88.84       003       92.76       003
# 4       005       87.94       005       88.42       002       93.01       002
#
#   Points_2019
# ...

# %%
# dropping/deleting unwanted columns
df.drop(columns=['Sr no','2023','2022','2021','2020','2019'],inplace=True)

# %%
df.columns
# Out:
# Index(['Country', 'Rank_2023', 'Points_2023', 'Rank_2022', 'Points_2022',
#        'Rank_2021', 'Points_2021', 'Rank_2019', 'Points_2019'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,5))
sns.distplot(df['Points_2023'], label='2023 Points')
sns.distplot(df['Points_2022'], label='2022 Points')
sns.distplot(df['Points_2021'], label='2021 Points')
sns.distplot(df['Points_2020'], label='2020 Points')
sns.distplot(df['Points_2019'], label='2019 Points')
plt.legend()
# Out:
# C:\Users\Public\Documents\iSkysoft\CreatorTemp\ipykernel_18764\2154801374.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Points_2023'], label='2023 Points')
# C:\Users\Public\Documents\iSkysoft\CreatorTemp\ipykernel_18764\2154801374.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
sns.histplot(df['Points_2023'], label='2023 Points')
sns.histplot(df['Points_2022'], label='2022 Points')
sns.histplot(df['Points_2021'], label='2021 Points')
plt.legend()

# %%
df.describe().style.format("{:.2f}").background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_d47f4_row0_col0, #T_d47f4_row0_col1, #T_d47f4_row0_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_d47f4_row1_col0, #T_d47f4_row1_col1, #T_d47f4_row1_col2, #T_d47f4_row5_col0, #T_d47f4_row5_col1, #T_d47f4_row5_col2 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_d47f4_row2_col0, #T_d47f4_row2_col1, #T_d47f4_row2_col2 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_d47f4_row3_col0, #T_d47f4_row3_col1, #T_d47f4_row3_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_d47f4_row4_col0, #T_d47f4_row4_col1, #T_d47f4_row4_col2 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_d47f4_row6_col0, #T_d47f4_row6_col1, #T_d47f4_row6_col2 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_d47f4_row7_col0, #T_d47f4_row7_col1, #T_d47f4_row7_col2 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d47f4">
#   <thead>
#     <tr>
# ...

# %%
# all unique country
df['Country'].nunique()
# Out:
# 181

# %%
sns.displot(df['Points_2023'])
plt.title("Histogram of Points 2023")

sns.displot(df['Points_2022'])
plt.title("Histogram of Points 2022")

sns.displot(df['Points_2021'])
plt.title("Histogram of Points 2021")

sns.displot(df['Points_2020'])
plt.title("Histogram of Points 2020")

sns.displot(df['Points_2019'])
plt.title("Histogram of Points 2019")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Points_2020'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
sns.distplot(df['Points_2023'])
sns.distplot(df['Points_2022'])
sns.distplot(df['Points_2021'])
sns.distplot(df['Points_2020'])
sns.distplot(df['Points_2019'])
# Out:
# C:\Users\Public\Documents\iSkysoft\CreatorTemp\ipykernel_18764\2928358890.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Points_2023'])
# C:\Users\Public\Documents\iSkysoft\CreatorTemp\ipykernel_18764\2928358890.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.histplot(df['Points_2023'], label='2023 Points')
sns.histplot(df['Points_2022'], label='2022 Points')
sns.histplot(df['Points_2021'], label='2021 Points')
plt.legend()
